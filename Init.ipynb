# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 8.0 MB/s eta 0:00:00
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 23.6 MB/s eta 0:00:00
# Collecting statsmodels==0.13.5
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 63.4 MB/s eta 0:00:00
# Collecting patsy>=0.5.2
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 44.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: scipy>=1.3 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 3)) (1.9.3)
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pandas>=0.25 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 3)) (2.1.4)
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.5->-r ./requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.5->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.5->-r ./requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->statsmodels==0.13.5->-r ./requirements.txt (line 3)) (1.17.0)
# Installing collected packages: xlrd, patsy, et-xmlfile, openpyxl, statsmodels
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5 patsy-1.0.1 statsmodels-0.13.5 xlrd-2.0.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
